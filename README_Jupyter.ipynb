# %% [markdown]
# # Readme

# %%
from IPython.display import Audio,Image, YouTubeVideo
id='TZCO3faFQPs'
VideoWidth=1280
VideoHeight=720
scale = 0.7
YouTubeVideo(id=id,width=VideoWidth*scale,height=VideoHeight*scale)

# %% [markdown]
# # Intro
